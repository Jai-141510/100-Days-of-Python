# %% [markdown]
# ## Project - Generate a band name using city you grew up in and the name of your pet

# %%
# Welcoming the user
print("Welcome to the Band Name Generator!")

# Assigning variable for city
userinput_city = input("What is the name of the city you grew up in?")

# Assigning variable for the name of the pet
userinput_pet = input("What is the name of your pet?")

# Providing an output for the band name by combining city and pet names
print(f"Your band name could be {userinput_city} {userinput_pet}")
# Out:
# Welcome to the Band Name Generator!
# Your band name could be Chennai Sushi
