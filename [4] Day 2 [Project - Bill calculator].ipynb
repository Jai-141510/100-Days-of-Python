# %% [markdown]
# ## Building a bill calculator which includes tip amount and total split between the members

# %%
# Asking user for the bill amount before tip
userinput_billamt = int(input("Enter the bill amount: "))

# Asking user for the tip percentage
userinput_tip_percent = float(input("What percentage would you like to tip - 10, 12 or 15 ?: "))

# Calculating the final total bill after tips
final_bill = (userinput_billamt * userinput_tip_percent / 100) + userinput_billamt

# Asking user for the number of people to split
userinput_peoplecount = int(input("How many people would you like to split this with? : "))

# Calculating the split
final_split = final_bill / userinput_peoplecount

# Giving the user the split amount
print(f"The final split will be {final_split} per person")
# Out:
# The final split will be 112.0 per person
