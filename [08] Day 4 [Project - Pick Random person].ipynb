# %% [markdown]
# ## Creating a project where a random person is selected from the list of people

# %%
# Creating a list of people
names = ['Alice', 'Bob', 'Charlie', 'David', 'Emma']


# Importing random
import random as rd

# Using random.choice to choose random name from the list
rd.choice(names)
# Out:
# 'Charlie'
